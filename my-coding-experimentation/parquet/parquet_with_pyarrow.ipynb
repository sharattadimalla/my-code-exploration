# %% [markdown]
# # Install pyarrow

# %%
# %%sh
# pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.7/site-packages (from pyarrow) (1.16.1)
# Requirement already satisfied: six>=1.0.0 in /usr/local/lib/python3.7/site-packages (from pyarrow) (1.12.0)
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Import necessary modules

# %%
import pyarrow.parquet as pq
import numpy as np
import pandas as pd

# %% [markdown]
# ## Setup data

# %%
import random
import uuid
import json

def gen_sample_acct():
    return dict(acct_id=random.randint(1,99999999),acct_feature1=str(uuid.uuid4()))

def gen_sample_accounts(num_records):
    accts = [gen_sample_acct() for i in range(num_records)]
    return accts

def write_json(sample_dict, filename):
    with open(filename, 'w') as f:
        f.write(json.dumps(sample_dict))
    return "success"

# %% [markdown]
# ## Generate sample data

# %%
sample_accts = gen_sample_accounts(5)
write_json(sample_accts, 'sample_accounts_pyarrow.json')
# Out:
# 'success'

# %%
# %%sh
# ls -lt | grep -i "sample_"
# Out:
# -rw-r--r--  1 sharattadimalla  staff    399 Nov 11 10:41 sample_accounts_pyarrow.json
# drwxr-xr-x  6 sharattadimalla  staff    192 Nov 10 12:43 sample_accounts.parquet
# drwxr-xr-x  6 sharattadimalla  staff    192 Nov 10 12:43 sample_customer.parquet
# -rw-r--r--  1 sharattadimalla  staff  16784 Nov 10 12:42 sample_customers.json
# -rw-r--r--  1 sharattadimalla  staff    399 Nov 10 12:40 sample_accounts.json
# -rw-r--r--  1 sharattadimalla  staff  16787 Nov 10 12:33 sample_data.json
# drwxr-xr-x  6 sharattadimalla  staff    192 Nov 10 11:43 sample_data.parquet

# %%
sample_accts
# Out:
# [{'acct_id': 30071544,
#   'acct_feature1': 'ab4a7c54-7f98-4d64-a874-3972286e1cbf'},
#  {'acct_id': 53960302,
#   'acct_feature1': '7820eb21-3b92-4b79-89b1-76e4c0046a0b'},
#  {'acct_id': 18450629,
#   'acct_feature1': 'e04384c0-55af-4fdb-b7bb-a8474f1fd3bb'},
#  {'acct_id': 80074688,
#   'acct_feature1': 'b10ddc34-a62b-42f9-8540-134a103e6a41'},
#  {'acct_id': 7222352, 'acct_feature1': 'c5a38824-e656-4c89-9770-a55c5d0dd84c'}]

# %% [markdown]
# ## Create pandas dataframe

# %%
df = pd.DataFrame(sample_accts)

# %%
df.head()
# Out:
#                           acct_feature1   acct_id
# 0  ab4a7c54-7f98-4d64-a874-3972286e1cbf  30071544
# 1  7820eb21-3b92-4b79-89b1-76e4c0046a0b  53960302
# 2  e04384c0-55af-4fdb-b7bb-a8474f1fd3bb  18450629
# 3  b10ddc34-a62b-42f9-8540-134a103e6a41  80074688
# 4  c5a38824-e656-4c89-9770-a55c5d0dd84c   7222352

# %% [markdown]
# ## Create pyarrow table

# %%
import pyarrow as pa
table = pa.Table.from_pandas(df)

# %%
table
# Out:
# pyarrow.Table
# acct_feature1: string
# acct_id: int64
# __index_level_0__: int64
# metadata
# --------
# OrderedDict([(b'pandas',
#               b'{"index_columns": ["__index_level_0__"], "column_indexes": ['
#               b'{"name": null, "field_name": null, "pandas_type": "unicode",'
#               b' "numpy_type": "object", "metadata": {"encoding": "UTF-8"}}]'
#               b', "columns": [{"name": "acct_feature1", "field_name": "acct_'
#               b'feature1", "pandas_type": "unicode", "numpy_type": "object",'
#               b' "metadata": null}, {"name": "acct_id", "field_name": "acct_'
#               b'id", "pandas_type": "int64", "numpy_type": "int64", "metadat'
#               b'a": null}, {"name": null, "field_name": "__index_level_0__",'
#               b' "pandas_type": "int64", "numpy_type": "int64", "metadata": '
#               b'null}], "pandas_version": "0.24.1"}')])

# %% [markdown]
# ## Write flattened parquet

# %%
pq.write_table(table, 'sample_accounts_pyarrow.parquet')

# %%
# %%sh
# ls -lt | grep -i "sample_"
# Out:
# -rw-r--r--  1 sharattadimalla  staff   1873 Nov 11 10:49 sample_accounts_pyarrow.parquet
# -rw-r--r--  1 sharattadimalla  staff    399 Nov 11 10:41 sample_accounts_pyarrow.json
# drwxr-xr-x  6 sharattadimalla  staff    192 Nov 10 12:43 sample_accounts.parquet
# drwxr-xr-x  6 sharattadimalla  staff    192 Nov 10 12:43 sample_customer.parquet
# -rw-r--r--  1 sharattadimalla  staff  16784 Nov 10 12:42 sample_customers.json
# -rw-r--r--  1 sharattadimalla  staff    399 Nov 10 12:40 sample_accounts.json
# -rw-r--r--  1 sharattadimalla  staff  16787 Nov 10 12:33 sample_data.json
# drwxr-xr-x  6 sharattadimalla  staff    192 Nov 10 11:43 sample_data.parquet

# %% [markdown]
# ## Setup nested data

# %%
def gen_sample_accounts(num_records):
    accts = [gen_sample_acct() for i in range(num_records)]
    return accts

def gen_sample_app():
    return dict(app_id=random.randint(1,99999999),app_feature1=str(uuid.uuid4()))

def gen_sample_apps(num_records):
    apps = [gen_sample_app() for i in range(num_records)]
    return apps

def gen_sample_customers(num_records):
    customers = [dict(cust_id=random.randint(1,99999999),
                      cust_feature1=str(uuid.uuid4()),
                      accts=gen_sample_accounts(num_records),
                      apps=gen_sample_apps(num_records)
                      ) for i in range(num_records)]
    return customers

sample_customers = gen_sample_customers(10)
sample_customers
# Out:
# [{'cust_id': 10538913,
#   'cust_feature1': '55a5ff61-9142-4168-8b27-e05ae499d512',
#   'accts': [{'acct_id': 62043918,
#     'acct_feature1': '268612ff-dc97-4bd3-91b4-82331dc65aab'},
#    {'acct_id': 45452152,
#     'acct_feature1': 'f8710128-421d-42de-bbba-b3bed9ca02c0'},
#    {'acct_id': 53535005,
#     'acct_feature1': '9b948278-9434-4d96-99f8-330347f18b89'},
#    {'acct_id': 74679862,
#     'acct_feature1': 'a8638b27-5bea-409b-bd89-a1747d1dc68a'},
#    {'acct_id': 55054665,
#     'acct_feature1': 'cd8f75a9-7a57-4ed2-b09d-cb751b29b36e'},
#    {'acct_id': 66588038,
#     'acct_feature1': '2ccb8c6f-a6ef-4cca-8981-4ea36a377b45'},
#    {'acct_id': 22050796,
#     'acct_feature1': 'cebd1b49-69ec-4f33-9cc4-569f589b5e3f'},
#    {'acct_id': 58403517,
#     'acct_feature1': '1d0bb441-e374-4451-a4ad-4502555fe346'},
#    {'acct_id': 51240810,
#     'acct_feature1': 'afb89e41-745e-4744-a4a7-63cfdd8a09be'},
#    {'acct_id': 74760271,
#     'acct_feature1': 'd311afc2-f5b3-4282-ac49-5e90c3527f67'}],
#   'apps': [{'app_id': 56607329,
#     'app_feature1': '6873be81-5eea-40da-b466-5f755837b9c1'},
#    {'app_id': 83703506,
#     'app_feature1': '2385e2cc-a472-482e-bf88-b041223e9545'},
#    {'app_id': 36354091,
#     'app_feature1': '199a1a55-7f40-4fd4-93fc-c97248f6082e'},
#    {'app_id': 60541785,
#     'app_feature1': '1dca09e0-10f3-4da7-9beb-216a9b65ac04'},
#    {'app_id': 45914176,
#     'app_feature1': '6f1dee52-6dae-4162-ae35-10f4f0a86c39'},
#    {'app_id': 13982240,
#     'app_feature1': '9d6e54a1-52a5-4bc3-b620-aa6d378b9062'},
#    {'app_id': 65375734,
#     'app_feature1': 'e83d18b4-6cee-46c8-ba0f-12a4986a1c03'},
#    {'app_id': 46987476,
#     'app_feature1': 'da7f53db-8fa2-4b1a-8205-283a517c1b79'},
#    {'app_id': 59955175,
#     'app_feature1': 'b12c9ebb-6e42-4c5e-b0bc-22f3669457d4'},
#    {'app_id': 10859615,
#     'app_feature1': '98382268-7918-4e3e-aade-a90cc087bf6c'}]},
#  {'cust_id': 65127062,
#   'cust_feature1': '08a322f2-bede-4ebf-a1e0-badb86c395e4',
#   'accts': [{'acct_id': 37883031,
#     'acct_feature1': '334b606d-9159-4286-9519-0045220c01cc'},
#    {'acct_id': 36485276,
#     'acct_feature1': 'b555fff1-5b0e-4451-a2c2-4575871519d4'},
#    {'acct_id': 36567381,
#     'acct_feature1': 'f0322844-ae1a-42c8-8860-561dc301db7f'},
#    {'acct_id': 86514823,
#     'acct_feature1': 'b9cf8bbd-f519-4847-a6d7-6a9a6722924c'},
#    {'acct_id': 84046644,
#     'acct_feature1': '0c8bae92-f2d5-4aef-9863-681e4250f9c5'},
#    {'acct_id': 56160163,
#     'acct_feature1': 'e9c25db0-85fc-454e-865e-f4c4f4d502e0'},
#    {'acct_id': 44406628,
#     'acct_feature1': 'c0530f34-824f-4bb4-95ec-5b3897d68dfc'},
#    {'acct_id': 58950647,
#     'acct_feature1': '3478e782-4973-4dfa-9fed-a70b5ce89ef0'},
#    {'acct_id': 50935580,
#     'acct_feature1': '0ec33f6e-c1c2-427f-b1e0-13c991deac11'},
#    {'acct_id': 97691130,
#     'acct_feature1': 'cc63eddc-da6c-4a91-9423-5c1195617093'}],
#   'apps': [{'app_id': 39514391,
#     'app_feature1': '09948397-10ff-4bc9-abd4-b6c6421d9006'},
#    {'app_id': 17343246,
#     'app_feature1': '5f37a981-a7fb-4f23-82c2-dbfa2d31cd83'},
#    {'app_id': 87819106,
#     'app_feature1': 'b29ba01e-4541-440f-8768-2a3d6f51521c'},
#    {'app_id': 2129116, 'app_feature1': '6e51c015-93c5-49cf-9ace-9e15faf77e02'},
#    {'app_id': 7316544, 'app_feature1': '67ddaf98-f909-49cc-96a1-a231707a2eac'},
#    {'app_id': 66846416,
#     'app_feature1': '3d3d70b2-8ca4-4bf1-a9a4-6088823ceee3'},
#    {'app_id': 2646049, 'app_feature1': '446c087b-e24d-42cf-9962-aea59ec2e4b1'},
#    {'app_id': 12523067,
#     'app_feature1': 'e6a10e7e-d3f5-45af-a28e-5f6d66eaa87c'},
#    {'app_id': 86652715,
#     'app_feature1': '3ca24dd8-2334-4855-86b9-410b7ab484c8'},
#    {'app_id': 98810391,
#     'app_feature1': '7bb83606-a191-4ff5-88c3-c85ca8b60293'}]},
#  {'cust_id': 27430688,
#   'cust_feature1': 'aad812a4-f624-4fbe-ae57-29c456b9de92',
#   'accts': [{'acct_id': 14426869,
#     'acct_feature1': '3a9406c9-42a4-42b8-bea9-8843fea922e1'},
#    {'acct_id': 89377959,
#     'acct_feature1': 'c3f6a321-4e1a-4338-a95d-fd2a0153bb81'},
#    {'acct_id': 36423050,
#     'acct_feature1': '713dfadd-609c-4efe-9ffc-d6b8cbac6b51'},
#    {'acct_id': 73146217,
#     'acct_feature1': '8ad65372-2659-460d-b40c-d207de802247'},
#    {'acct_id': 83793220,
#     'acct_feature1': '6c0b5bc5-3f57-4d41-ab8e-ada63c034fc8'},
#    {'acct_id': 91328967,
#     'acct_feature1': '36890986-a545-4b5e-81ff-14bf29508f8a'},
#    {'acct_id': 5746000,
#     'acct_feature1': '49b74461-2b5d-409b-9592-c94e92582aaa'},
#    {'acct_id': 53317709,
#     'acct_feature1': 'c854dbbe-40f2-40fa-8f93-46074176a014'},
#    {'acct_id': 61467706,
#     'acct_feature1': 'aeab1754-88f5-4b7b-95b5-d38fba4338c0'},
#    {'acct_id': 8071864,
#     'acct_feature1': 'f47352e4-0ab1-4574-a1a1-6075be68efde'}],
#   'apps': [{'app_id': 77031006,
#     'app_feature1': '47aad62f-71fb-47b9-b075-9ab46eb8be6a'},
#    {'app_id': 41888492,
#     'app_feature1': '6b2fc373-70f0-436b-9b86-fe1573042c51'},
#    {'app_id': 19492836,
#     'app_feature1': 'bdd0077d-226a-427f-8227-5d2e8ad5bb0e'},
#    {'app_id': 16628879,
#     'app_feature1': '224532f4-9c9a-494f-8297-8b7597579c7f'},
#    {'app_id': 48504646,
#     'app_feature1': 'c385113b-f8fd-4fd4-b8f7-17c01853d697'},
#    {'app_id': 81725397,
#     'app_feature1': 'c638f323-0f15-475e-be72-b8cf05099622'},
#    {'app_id': 98187482,
#     'app_feature1': '77928628-29bc-411f-b483-b56de1379fec'},
#    {'app_id': 7341671, 'app_feature1': 'd4a6efad-f5ff-413b-aa8e-2caf0dbb9aa9'},
#    {'app_id': 83641870,
#     'app_feature1': '265d0a0b-8612-4d51-9ed5-3d566fd9b5bb'},
#    {'app_id': 49180802,
#     'app_feature1': '7183b8d7-a298-487c-bd2d-88f435f3aa2b'}]},
#  {'cust_id': 34158639,
#   'cust_feature1': '80594cc2-def4-4623-aa03-773254905766',
#   'accts': [{'acct_id': 48328287,
#     'acct_feature1': 'c784dbad-309b-4e03-ba60-725548fe45e8'},
#    {'acct_id': 20288772,
#     'acct_feature1': 'c982d56e-0ba1-47a4-8c99-5f266623ee34'},
#    {'acct_id': 63897981,
#     'acct_feature1': '89f145e0-9a5d-43bd-88ba-c7edd99b0bad'},
#    {'acct_id': 95162532,
#     'acct_feature1': '86a5fa6e-f919-4bcd-a397-41b886d2eeb1'},
#    {'acct_id': 29710315,
#     'acct_feature1': '41c7d1c6-61d8-4483-af85-01b2a8c3cd47'},
#    {'acct_id': 72662126,
#     'acct_feature1': '52dfb648-acca-457a-a8e9-81afc96d9a06'},
#    {'acct_id': 53039217,
#     'acct_feature1': '0700d3e2-4440-4d19-bd45-b8add6e142f3'},
#    {'acct_id': 68188945,
#     'acct_feature1': 'e1037b9a-0ff5-45f1-b58b-3ed310bb8f10'},
#    {'acct_id': 45099801,
#     'acct_feature1': '4bc85ac3-fab3-4c12-ad80-c4ca4af84e8b'},
#    {'acct_id': 52162700,
#     'acct_feature1': 'fe34e5ae-3422-4a0f-b7d1-25aa05ab67a1'}],
#   'apps': [{'app_id': 52396176,
#     'app_feature1': '7d991b39-d374-47ec-8c3a-5ac1dde20498'},
#    {'app_id': 20607968,
#     'app_feature1': '28402f66-4d03-459f-b7ff-fbce2dc15334'},
#    {'app_id': 45645525,
#     'app_feature1': '60e76c62-b978-4de9-8ad4-333b667cc1fd'},
#    {'app_id': 48961343,
#     'app_feature1': '7fe93dcb-e0c0-4b19-9d61-4166ccede0e8'},
#    {'app_id': 16201686,
#     'app_feature1': 'b1332ab2-0a7a-4ad6-879a-9e18b359bd68'},
#    {'app_id': 90664148,
#     'app_feature1': 'cbc1bf79-c88e-47e4-85b3-8a135c1356e0'},
#    {'app_id': 9886133, 'app_feature1': '6155637c-c2ed-4c74-b512-876ab51a63b0'},
#    {'app_id': 26727996,
#     'app_feature1': '50675f77-b50b-4a37-b56c-5d8b1e367aa5'},
#    {'app_id': 56410810,
#     'app_feature1': '24936b0c-9418-42dd-b4c3-a3a92365edc7'},
#    {'app_id': 66305212,
#     'app_feature1': '27f8b767-7ac5-48de-b59f-23f3979b6ada'}]},
#  {'cust_id': 17037471,
#   'cust_feature1': '823cfaab-1252-4520-bc3f-d6925f293180',
#   'accts': [{'acct_id': 56401250,
#     'acct_feature1': 'ff07d684-9405-42a0-845c-020108fd780a'},
#    {'acct_id': 48180430,
#     'acct_feature1': '0aabbe22-ba7b-4453-abad-c3e14fd8bb54'},
#    {'acct_id': 91560905,
#     'acct_feature1': '5aab9417-2b5e-4b40-a6e7-a2b588c18940'},
#    {'acct_id': 88484142,
#     'acct_feature1': '7a2caf1e-fe29-4733-bcfe-4c401772c88c'},
#    {'acct_id': 47232603,
#     'acct_feature1': 'eb485b72-464f-47de-aa2c-205341c38db3'},
#    {'acct_id': 13289134,
#     'acct_feature1': 'b65c56a1-733a-40dc-91a5-18cd36ca19c1'},
#    {'acct_id': 75496605,
#     'acct_feature1': '983028e2-d73b-45a7-8e78-f5a046ea04be'},
#    {'acct_id': 78445306,
#     'acct_feature1': '376ca2d9-52db-4fa3-ba0e-9799613d39a4'},
#    {'acct_id': 32740656,
#     'acct_feature1': '28ca197f-3f98-45aa-b129-06e6230916b9'},
#    {'acct_id': 79424181,
#     'acct_feature1': 'c82952ee-eced-4ab6-a8e7-1aa9d5c16981'}],
#   'apps': [{'app_id': 73976825,
#     'app_feature1': '275862cc-74bc-4949-9bff-7fe2a7977758'},
#    {'app_id': 72768846,
#     'app_feature1': 'ed171d5f-d837-4866-910e-6da4412fa4f2'},
#    {'app_id': 47705421,
#     'app_feature1': '6114d0ee-8a21-4a18-a8f0-68ba054ffc92'},
#    {'app_id': 7313293, 'app_feature1': '1cd06fab-3faa-4c91-a4f1-c6eab68f3cb7'},
#    {'app_id': 41741555,
#     'app_feature1': '6b0d51cb-105f-40fc-9d25-53beef7d1cc1'},
#    {'app_id': 87756416,
#     'app_feature1': '6096b48a-c900-44e3-ac84-2905c5e0843d'},
#    {'app_id': 72692241,
#     'app_feature1': '1b0946d5-355d-4244-9505-58c9bd6162b5'},
#    {'app_id': 20902055,
#     'app_feature1': '94135edd-a431-45ab-852d-0b5e8422aad9'},
#    {'app_id': 32333194,
#     'app_feature1': '57f2d71d-3ec7-4a72-b8d2-33c9d960282e'},
#    {'app_id': 18196019,
#     'app_feature1': '8b73fa8b-386e-46cb-ad90-6687173de2a4'}]},
#  {'cust_id': 92033174,
#   'cust_feature1': '8f8ddd23-9a65-40df-b0d3-45c9bc04a24c',
#   'accts': [{'acct_id': 17316613,
#     'acct_feature1': '05a8656f-716e-4abb-9649-d3b6d80e0d63'},
#    {'acct_id': 25372335,
#     'acct_feature1': '4bf6effb-2ec1-4a3b-8ed0-cfee3584f858'},
#    {'acct_id': 26251242,
#     'acct_feature1': '55ca92d3-5144-4255-a623-a0bfa84c26b7'},
#    {'acct_id': 86511236,
#     'acct_feature1': '322995b2-3b17-4f42-9c48-35742f4455ab'},
#    {'acct_id': 12980428,
#     'acct_feature1': 'ffb1f07d-727d-47bb-bc41-41dad30b8352'},
#    {'acct_id': 40047656,
#     'acct_feature1': '4734a4a1-a065-4f2c-8f5b-ac06d4bdc5c9'},
#    {'acct_id': 17079358,
#     'acct_feature1': '54b21c16-77ae-4fd9-97f4-6bca83aee632'},
#    {'acct_id': 78300804,
#     'acct_feature1': '7b8cb14c-2a25-42e1-98e3-4bfe0bacd282'},
#    {'acct_id': 11743728,
#     'acct_feature1': '281a75b4-cffa-4c41-8920-867910512d00'},
#    {'acct_id': 79829210,
#     'acct_feature1': '4291fe98-528e-4267-b6bf-0b781f0f75b8'}],
#   'apps': [{'app_id': 15164287,
#     'app_feature1': 'bb04feeb-8755-47af-b544-ca4a6115b14a'},
#    {'app_id': 9284466, 'app_feature1': '9d7fc115-8348-4855-9c68-5650691446c8'},
#    {'app_id': 27536701,
#     'app_feature1': 'e564b308-8215-47db-af4d-ab84ef412773'},
#    {'app_id': 78457818,
#     'app_feature1': 'e891007e-e3da-4293-99f0-f4942ab7da5f'},
#    {'app_id': 37139918,
#     'app_feature1': '562494f3-bf0e-4661-9180-252e0bf149b5'},
#    {'app_id': 68300938,
#     'app_feature1': 'c1fca615-ea5b-457b-8e2a-344eed9cab3f'},
#    {'app_id': 24673573,
#     'app_feature1': 'ac44a23a-710a-4188-9f3b-bba1216dc85c'},
#    {'app_id': 51766931,
#     'app_feature1': '15a3c445-751e-407c-9e1f-8b69840b8474'},
#    {'app_id': 32647477,
#     'app_feature1': 'f1baa6c6-47b0-4947-b1fc-4595794776a9'},
#    {'app_id': 84711665,
#     'app_feature1': 'c612e5ff-d66b-44f3-831d-361fbdf0d7c9'}]},
#  {'cust_id': 33672896,
#   'cust_feature1': '1c132fb9-425e-4e5e-b93e-817966590de7',
#   'accts': [{'acct_id': 84751931,
#     'acct_feature1': '0c0c5cea-e44a-4266-9fc0-8c1a0749ed09'},
#    {'acct_id': 17044995,
#     'acct_feature1': 'cc0c7b83-42a1-402f-a2ce-40f2bb5d69fd'},
#    {'acct_id': 44646763,
#     'acct_feature1': '214882cf-548a-4bf0-8bc4-da4de3fbfad9'},
#    {'acct_id': 76190547,
#     'acct_feature1': 'a4149685-74c2-4c89-96a0-503d380dafb9'},
#    {'acct_id': 26794295,
#     'acct_feature1': '3ff11b12-b677-4f4a-8145-8319801f62a0'},
#    {'acct_id': 94266486,
#     'acct_feature1': '2ba4648e-cf51-406c-b22c-dc33abe96eac'},
#    {'acct_id': 32317223,
#     'acct_feature1': 'f66dde7b-3ffd-4ed1-8728-b4cfd44ffaa4'},
#    {'acct_id': 32326861,
#     'acct_feature1': 'a286608b-c863-4496-9df8-0a1e0411802c'},
#    {'acct_id': 62455876,
#     'acct_feature1': '75b95d9a-a6db-444b-9546-fa931f863692'},
#    {'acct_id': 45379698,
#     'acct_feature1': '5b4989f6-5540-4715-9341-3e3700eb1d02'}],
#   'apps': [{'app_id': 21426401,
#     'app_feature1': 'de9856e5-541e-45fb-89d2-3730e1e65f6c'},
#    {'app_id': 94977352,
#     'app_feature1': '3bede282-98aa-40e9-ba3d-8cbeefc1562c'},
#    {'app_id': 54624024,
#     'app_feature1': 'f5a90b47-eadd-4711-9eb7-3de90b45441e'},
#    {'app_id': 92500694,
#     'app_feature1': '54ebdb7b-f328-45f5-bc79-87cc7978390a'},
#    {'app_id': 38242836,
#     'app_feature1': '5cb5e2ac-a19a-4002-a905-0624211a27af'},
#    {'app_id': 57681538,
#     'app_feature1': '65d3842b-f67e-4c24-883e-b9dba823c220'},
#    {'app_id': 58309029,
#     'app_feature1': '27cbd8b9-e41b-40f1-8ce5-dc27d4e3dcd4'},
#    {'app_id': 69915407,
#     'app_feature1': '67a5a158-5112-4f02-b9d2-83cb1de52e3d'},
#    {'app_id': 55637572,
#     'app_feature1': '967f6cd6-e8c5-49eb-a4ed-2105885ec7bb'},
#    {'app_id': 82659959,
#     'app_feature1': 'c0f042f2-943c-4ef2-b4bf-6395aad08125'}]},
#  {'cust_id': 74176598,
#   'cust_feature1': 'c91d38c0-afb4-4e2a-af04-e3726f14182b',
#   'accts': [{'acct_id': 51328506,
#     'acct_feature1': '38ad9254-1e7a-493a-bac0-510c1fc383b4'},
#    {'acct_id': 95375644,
#     'acct_feature1': 'f7bf0d95-d9bc-46bc-ab75-1ef31358f693'},
#    {'acct_id': 46396420,
#     'acct_feature1': 'f34b914a-e1a5-46a4-b64c-21ef122292c7'},
#    {'acct_id': 32608957,
#     'acct_feature1': '35316425-8242-473e-9cc7-e3a9290225ac'},
#    {'acct_id': 76090142,
#     'acct_feature1': '5a4f0b40-f1ad-4ddc-aceb-e397bb12ed91'},
#    {'acct_id': 86230910,
#     'acct_feature1': 'c4294e4b-21a6-4ba6-afd6-087a49279737'},
#    {'acct_id': 45065617,
#     'acct_feature1': '7dcb42f8-1ac3-401d-a353-79e78aaab695'},
#    {'acct_id': 52692028,
#     'acct_feature1': '2bcd0fc8-8ebd-4d0e-8350-03fa27813c38'},
#    {'acct_id': 65183893,
#     'acct_feature1': 'dbd3bb97-fa7f-49cf-87db-67f626cef350'},
#    {'acct_id': 37681908,
#     'acct_feature1': 'ef622a58-fc48-40fb-949b-0127133240ad'}],
#   'apps': [{'app_id': 19495921,
#     'app_feature1': '135d8ac0-7b68-4f6d-91f8-f414d44646ea'},
#    {'app_id': 12120780,
#     'app_feature1': '066dd0ed-70ee-4819-8127-a56398af6274'},
#    {'app_id': 85076677,
#     'app_feature1': '0bf44c77-a082-4246-a01e-da15d86213ad'},
#    {'app_id': 41415183,
#     'app_feature1': 'cca6ddc6-1b7c-4475-9595-b8f622ecee80'},
#    {'app_id': 67548192,
#     'app_feature1': '2cebd19c-3be7-4d1c-b66c-af9185be8548'},
#    {'app_id': 78443372,
#     'app_feature1': '1043f1fd-ed2c-45b3-a425-a3c94f31a8ba'},
#    {'app_id': 61821147,
#     'app_feature1': 'c9ee8362-1232-448a-8248-1dc2130354e4'},
#    {'app_id': 79853572,
#     'app_feature1': 'd1cea7eb-728b-4162-93ed-1d76fff8f8b5'},
#    {'app_id': 64146120,
#     'app_feature1': 'aacbcab2-6540-4d63-9ba4-a7efcb948381'},
#    {'app_id': 56980956,
#     'app_feature1': '4e70728d-f17c-4503-b2ac-cca2b005f1d0'}]},
#  {'cust_id': 96883069,
#   'cust_feature1': '33135693-9759-4d4d-9c55-cdeb823272e9',
#   'accts': [{'acct_id': 5845426,
#     'acct_feature1': '7aa44a06-88b0-4de0-9a30-0fe9556d601b'},
#    {'acct_id': 82552079,
#     'acct_feature1': 'd24e1e93-843e-4e36-93b0-4a0409a630a6'},
#    {'acct_id': 50262458,
#     'acct_feature1': 'b1a9b4e3-c54c-4641-89a6-64926ab27e32'},
#    {'acct_id': 55830435,
#     'acct_feature1': '75b26980-2fbd-4693-8476-0726b4401b3b'},
#    {'acct_id': 41313165,
#     'acct_feature1': 'e8727323-29d7-4aee-ac55-7df40385be0e'},
#    {'acct_id': 85580528,
#     'acct_feature1': '60d7c5d0-cd60-4c5b-96ef-a97d529a0a1d'},
#    {'acct_id': 54099303,
#     'acct_feature1': 'f50731ec-b0b9-4dd7-9c0e-1a99f78454fa'},
#    {'acct_id': 75584075,
#     'acct_feature1': '53c2338b-8d31-45ad-83cf-a74be72d076b'},
#    {'acct_id': 60811021,
#     'acct_feature1': 'd0543b3a-fb2a-4de0-8c4a-1bdbd5382900'},
#    {'acct_id': 57859321,
#     'acct_feature1': '2646208f-9936-4ff1-aa34-613fa830aeb2'}],
#   'apps': [{'app_id': 83279273,
#     'app_feature1': '4b256374-6617-4aec-ac96-bb42b710643f'},
#    {'app_id': 96883741,
#     'app_feature1': 'e827e551-eb16-4695-8030-13761c822e20'},
#    {'app_id': 80815835,
#     'app_feature1': '66594ca5-8501-4de8-bb6c-3c4f58877617'},
#    {'app_id': 98492769,
#     'app_feature1': '90235b2e-7da8-4682-82b9-cbee9da1243d'},
#    {'app_id': 90060183,
#     'app_feature1': 'a081b4d8-663b-4229-80cc-07bcaa809ca3'},
#    {'app_id': 76945224,
#     'app_feature1': '33623526-6e55-487b-8cbf-ba114c858c8b'},
#    {'app_id': 62014541,
#     'app_feature1': '30838ebb-f159-4e78-9ab3-24e9759f26e1'},
#    {'app_id': 6503403, 'app_feature1': '9db8dbf6-9734-48e8-9b6b-2b403389f11c'},
#    {'app_id': 51348028,
#     'app_feature1': '4c70ebc7-bb5c-4470-bab2-d0c362ff52b5'},
#    {'app_id': 66282051,
#     'app_feature1': '0c65aacf-423d-466c-8429-16c28958459c'}]},
#  {'cust_id': 86065899,
#   'cust_feature1': 'ab718e07-080f-4aa1-9302-f96db0b73061',
#   'accts': [{'acct_id': 34905039,
#     'acct_feature1': 'ee00f235-5817-403e-91ff-21fc49fe9ffb'},
#    {'acct_id': 42468701,
#     'acct_feature1': '101472b7-9e03-47a6-853e-de09271d9676'},
#    {'acct_id': 21834593,
#     'acct_feature1': '1dbbd932-7550-4433-86cb-afc04ff95c17'},
#    {'acct_id': 84989945,
#     'acct_feature1': 'd7139b55-59b7-401a-92e8-9d1ab6e2542e'},
#    {'acct_id': 12084643,
#     'acct_feature1': '82f46c33-cb20-4d1d-9e3f-fd923203b543'},
#    {'acct_id': 8310100,
#     'acct_feature1': 'd91d7a5a-5f82-45bc-977b-accfe1cb7ef2'},
#    {'acct_id': 13466430,
#     'acct_feature1': '64fd6813-7fab-42d8-80a1-163bbab2a79d'},
#    {'acct_id': 92610662,
#     'acct_feature1': 'b0d57da7-e992-45b8-a240-d20a19577982'},
#    {'acct_id': 31601170,
#     'acct_feature1': '64b06e82-a6a8-40d4-abb3-c7065cca657f'},
#    {'acct_id': 60321860,
#     'acct_feature1': 'e486c9a4-0978-4f4f-bcfd-418ce372eabe'}],
#   'apps': [{'app_id': 54700658,
#     'app_feature1': 'a6caac52-9564-43e7-9a9b-9ce189f36adf'},
#    {'app_id': 35705651,
#     'app_feature1': 'cd19a487-62f6-4d6b-b1af-ca534118f054'},
#    {'app_id': 35084712,
#     'app_feature1': '70f2d3ba-58c2-4269-b1f3-e73c9a54dba0'},
#    {'app_id': 36208528,
#     'app_feature1': '63f59d79-46ac-4471-9a1e-dd744614a0a7'},
#    {'app_id': 82756753,
#     'app_feature1': '3d73bb34-fc01-4a3e-9de1-5cac1701594f'},
#    {'app_id': 69425937,
#     'app_feature1': 'b9e3d810-2bfd-4cc5-b085-abcf02427dee'},
#    {'app_id': 81695088,
#     'app_feature1': 'ddc72d4e-8695-4c07-a86c-6401b8806c38'},
#    {'app_id': 5094749, 'app_feature1': 'b0bf3443-2edf-45ba-a5ac-f507c9b754db'},
#    {'app_id': 265495, 'app_feature1': '6862005b-4c8e-4590-bf43-7a005c4be850'},
#    {'app_id': 78815699,
#     'app_feature1': 'f7401f09-9862-4825-b0a7-75b296371e3a'}]}]

# %%
df_nested = pd.DataFrame(sample_customers)

# %%
df_nested.head()
# Out:
#                                                accts  \
# 0  [{'acct_id': 62043918, 'acct_feature1': '26861...
# 1  [{'acct_id': 37883031, 'acct_feature1': '334b6...
# 2  [{'acct_id': 14426869, 'acct_feature1': '3a940...
# 3  [{'acct_id': 48328287, 'acct_feature1': 'c784d...
# 4  [{'acct_id': 56401250, 'acct_feature1': 'ff07d...
#
#                                                 apps  \
# 0  [{'app_id': 56607329, 'app_feature1': '6873be8...
# 1  [{'app_id': 39514391, 'app_feature1': '0994839...
# 2  [{'app_id': 77031006, 'app_feature1': '47aad62...
# 3  [{'app_id': 52396176, 'app_feature1': '7d991b3...
# 4  [{'app_id': 73976825, 'app_feature1': '275862c...
#
#                           cust_feature1   cust_id
# 0  55a5ff61-9142-4168-8b27-e05ae499d512  10538913
# 1  08a322f2-bede-4ebf-a1e0-badb86c395e4  65127062
# 2  aad812a4-f624-4fbe-ae57-29c456b9de92  27430688
# 3  80594cc2-def4-4623-aa03-773254905766  34158639
# 4  823cfaab-1252-4520-bc3f-d6925f293180  17037471

# %% [markdown]
# ## Create a pyarrow table

# %%
table_nested = pa.Table.from_pandas(df_nested)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py in get_logical_type(arrow_type)
#      76     try:
# ---> 77         return logical_type_map[arrow_type.id]
#      78     except KeyError:
#
# KeyError: 23
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py in get_logical_type(arrow_type)
#      76     try:
# ---> 77         return logical_type_map[arrow_type.id]
#      78     except KeyError:
#
# KeyError: 24
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-30-2ea51cc2437f> in <module>
# ----> 1 table_nested = pa.Table.from_pandas(df_nested)
#
# /usr/local/lib/python3.7/site-packages/pyarrow/table.pxi in pyarrow.lib.Table.from_pandas()
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     441     metadata = construct_metadata(
#     442         df, column_names, index_columns, index_column_names, preserve_index,
# --> 443         types
#     444     )
#     445
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py in construct_metadata(df, column_names, index_levels, index_column_names, preserve_index, types)
#     215             field_name=sanitized_name
#     216         ) for col_name, sanitized_name, arrow_type in zip(
# --> 217             df.columns, column_names, df_types
#     218         )
#     219     ]
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py in <listcomp>(.0)
#     214             arrow_type=arrow_type,
#     215             field_name=sanitized_name
# --> 216         ) for col_name, sanitized_name, arrow_type in zip(
#     217             df.columns, column_names, df_types
#     218         )
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py in get_column_metadata(column, name, arrow_type, field_name)
#     158     dict
#     159     """
# --> 160     logical_type = get_logical_type(arrow_type)
#     161
#     162     string_dtype, extra_metadata = get_extension_dtype_info(column)
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py in get_logical_type(arrow_type)
#      80             return 'categorical'
#      81         elif isinstance(arrow_type, pa.lib.ListType):
# ---> 82             return 'list[{}]'.format(get_logical_type(arrow_type.value_type))
#      83         elif isinstance(arrow_type, pa.lib.TimestampType):
#      84             return 'datetimetz' if arrow_type.tz is not None else 'datetime'
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py in get_logical_type(arrow_type)
#      85         elif isinstance(arrow_type, pa.lib.Decimal128Type):
#      86             return 'decimal'
# ---> 87         raise NotImplementedError(str(arrow_type))
#      88
#      89
#
# NotImplementedError: struct<acct_feature1: string, acct_id: int64>

# %% [markdown]
# ## Nested data is not supported in pyarrow!
